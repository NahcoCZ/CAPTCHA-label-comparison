# %%
import subprocess
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from random import randint
from sklearn.model_selection import train_test_split
from IPython.display import clear_output
from tensorflow.keras import layers

# %%
# Load downloaded data into numpy.ndarray
X = np.load("../image_data.npy")
Y = np.load("../label_data.npy")

# Declare label names and declaring functions for later use
label_names = [
    'Bicycle', 'Bridge', 'Bus', 'Car', 'Chimney',
    'Crosswalk', 'Hydrant', 'Motorcycle', 'Other', 'Palm', 'Stair',
    'Traffic Light'
]


def decodeDataset(coded):
    return label_names[np.argmax(coded, axis=1)]


def decode(label):
    return label_names[np.argmax(label)]


def plotImage(img, label):
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(label)
    plt.imshow(img)
    plt.show()

# %%
# Split the training and testing data
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2, random_state=69)

# %%
# Defining compilation and training functions
def compile(model, epoch):
  # Compilation using adam optimization algorithm
  model.compile(
    optimizer="adam",
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=["accuracy"]
  ) 
  history = model.fit(
    xtrain,
    ytrain,
    epochs=epoch,
    validation_data=(xtest, ytest)
  )
  return model, history

def setfigure():
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.ylim([0, 1])
  plt.legend(loc='lower right')
  plt.show()

def lossfigure():
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc='lower right')
  plt.show()

def evaluate(history):
  plt.plot(history.history['accuracy'], label='accuracy')
  plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
  setfigure()
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  lossfigure()

def checkmodel(model, epoch):
  result, hist = compile(model, epoch)
  evaluate(hist)
  test_loss, test_acc = result.evaluate(xtest, ytest, verbose=2)
  return result, hist

def comparegraph(hist1, hist2):
  hist = [hist1, hist2]
  for i in hist:
    plt.plot(i.history['accuracy'], label='accuracy')
  setfigure()

  for i in hist:
    plt.plot(i.history['val_accuracy'], label = 'val_accuracy')
  setfigure()

def compareacc(model1, model2):
  model1.evaluate(xtest, ytest, verbose=2)
  model2.evaluate(xtest, ytest, verbose=2)

# %%
tf.keras.backend.clear_session()
model1 = tf.keras.models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((3, 3)),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.MaxPooling2D((3, 3)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(12, activation='softmax')
])
model1.summary()
model1, history1 = compile(model1, 15)
evaluate(history1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 128)       36992
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 256)       295168
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 64)                262208
#
#  dense_1 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 596,044
# Trainable params: 596,044
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 441/441 [==============================] - 12s 20ms/step - loss: 2.4439 - accuracy: 0.3405 - val_loss: 1.7736 - val_accuracy: 0.4112
# Epoch 2/10
# 441/441 [==============================] - 8s 18ms/step - loss: 1.6344 - accuracy: 0.4640 - val_loss: 1.4842 - val_accuracy: 0.5199
# Epoch 3/10
# 441/441 [==============================] - 8s 18ms/step - loss: 1.3841 - accuracy: 0.5540 - val_loss: 1.3024 - val_accuracy: 0.5805
# Epoch 4/10
# 441/441 [==============================] - 8s 18ms/step - loss: 1.1996 - accuracy: 0.6084 - val_loss: 1.2211 - val_accuracy: 0.5987
# Epoch 5/10
# 441/441 [==============================] - 8s 18ms/step - loss: 1.0549 - accuracy: 0.6515 - val_loss: 1.1619 - val_accuracy: 0.6214
# Epoch 6/10
# 441/441 [==============================] - 8s 18ms/step - loss: 0.9039 - accuracy: 0.6981 - val_loss: 1.2289 - val_accuracy: 0.5993
# Epoch 7/10
# 441/441 [==============================] - 8s 18ms/step - loss: 0.7996 - accuracy: 0.7272 - val_loss: 1.2833 - val_accuracy: 0.5862
# Epoch 8/10
# 441/441 [==============================] - 8s 18ms/step - loss: 0.6896 - accuracy: 0.7619 - val_loss: 1.3830 - val_accuracy: 0.6010
# Epoch 9/10
# 441/441 [==============================] - 8s 18ms/step - loss: 0.5963 - accuracy: 0.7944 - val_loss: 1.5161 - val_accuracy: 0.6001
# Epoch 10/10
# 441/441 [==============================] - 8s 18ms/step - loss: 0.5179 - accuracy: 0.8202 - val_loss: 1.6037 - val_accuracy: 0.6061

# %%
tf.keras.backend.clear_session()
model2 = tf.keras.models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((3, 3)),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dense(12, activation='softmax')
])
model2.summary()
model2, history2 = compile(model2, 15)
evaluate(history2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 128)       36992
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 256)       295168
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 350,284
# Trainable params: 350,284
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 441/441 [==============================] - 9s 19ms/step - loss: 2.4186 - accuracy: 0.3561 - val_loss: 1.7952 - val_accuracy: 0.3953
# Epoch 2/10
# 441/441 [==============================] - 8s 19ms/step - loss: 1.5276 - accuracy: 0.4983 - val_loss: 1.3746 - val_accuracy: 0.5380
# Epoch 3/10
# 441/441 [==============================] - 8s 19ms/step - loss: 1.3129 - accuracy: 0.5655 - val_loss: 1.2469 - val_accuracy: 0.5882
# Epoch 4/10
# 441/441 [==============================] - 8s 19ms/step - loss: 1.1615 - accuracy: 0.6115 - val_loss: 1.2107 - val_accuracy: 0.6018
# Epoch 5/10
# 441/441 [==============================] - 8s 19ms/step - loss: 1.0476 - accuracy: 0.6471 - val_loss: 1.0243 - val_accuracy: 0.6566
# Epoch 6/10
# 441/441 [==============================] - 8s 19ms/step - loss: 0.9598 - accuracy: 0.6791 - val_loss: 0.9758 - val_accuracy: 0.6713
# Epoch 7/10
# 441/441 [==============================] - 8s 19ms/step - loss: 0.8847 - accuracy: 0.6986 - val_loss: 0.9952 - val_accuracy: 0.6724
# Epoch 8/10
# 441/441 [==============================] - 8s 19ms/step - loss: 0.8283 - accuracy: 0.7188 - val_loss: 0.9913 - val_accuracy: 0.6600
# Epoch 9/10
# 441/441 [==============================] - 8s 19ms/step - loss: 0.7647 - accuracy: 0.7417 - val_loss: 0.8063 - val_accuracy: 0.7309
# Epoch 10/10
# 441/441 [==============================] - 8s 19ms/step - loss: 0.7143 - accuracy: 0.7578 - val_loss: 0.9060 - val_accuracy: 0.7005

# %%
tf.keras.backend.clear_session()
model3 = tf.keras.models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((3, 3)),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(12, activation='softmax')
])
model3.summary()
model3, history3 = compile(model3, 15)
evaluate(history3)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 128)       36992
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 256)       295168
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 350,284
# Trainable params: 350,284
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 441/441 [==============================] - 9s 19ms/step - loss: 2.2242 - accuracy: 0.3773 - val_loss: 1.5119 - val_accuracy: 0.5065
# Epoch 2/15
# 441/441 [==============================] - 8s 19ms/step - loss: 1.4859 - accuracy: 0.5096 - val_loss: 1.4704 - val_accuracy: 0.5113
# Epoch 3/15
# 441/441 [==============================] - 8s 19ms/step - loss: 1.3189 - accuracy: 0.5623 - val_loss: 1.1670 - val_accuracy: 0.6029
# Epoch 4/15
# 441/441 [==============================] - 8s 19ms/step - loss: 1.1974 - accuracy: 0.6017 - val_loss: 1.0619 - val_accuracy: 0.6517
# Epoch 5/15
# 441/441 [==============================] - 8s 19ms/step - loss: 1.0907 - accuracy: 0.6376 - val_loss: 1.0145 - val_accuracy: 0.6659
# Epoch 6/15
# 441/441 [==============================] - 8s 19ms/step - loss: 1.0192 - accuracy: 0.6615 - val_loss: 0.9164 - val_accuracy: 0.6931
# Epoch 7/15
# 441/441 [==============================] - 8s 19ms/step - loss: 0.9433 - accuracy: 0.6817 - val_loss: 0.9084 - val_accuracy: 0.6892
# Epoch 8/15
# 441/441 [==============================] - 8s 19ms/step - loss: 0.8913 - accuracy: 0.6982 - val_loss: 0.8841 - val_accuracy: 0.6974
# Epoch 9/15
# 441/441 [==============================] - 8s 19ms/step - loss: 0.8290 - accuracy: 0.7157 - val_loss: 0.8272 - val_accuracy: 0.7153
# Epoch 10/15
# 441/441 [==============================] - 9s 19ms/step - loss: 0.7811 - accuracy: 0.7326 - val_loss: 0.8151 - val_accuracy: 0.7252
# Epoch 11/15
# 441/441 [==============================] - 9s 20ms/step - loss: 0.7279 - accuracy: 0.7489 - val_loss: 0.8385 - val_accuracy: 0.7175
# Epoch 12/15
# 441/441 [==============================] - 9s 20ms/step - loss: 0.6718 - accuracy: 0.7691 - val_loss: 0.8580 - val_accuracy: 0.7121
# Epoch 13/15
# 441/441 [==============================] - 9s 20ms/step - loss: 0.6330 - accuracy: 0.7829 - val_loss: 0.8168 - val_accuracy: 0.7280
# Epoch 14/15
# 441/441 [==============================] - 9s 19ms/step - loss: 0.5913 - accuracy: 0.7940 - val_loss: 0.7853 - val_accuracy: 0.7374
# Epoch 15/15
# 441/441 [==============================] - 9s 19ms/step - loss: 0.5450 - accuracy: 0.8076 - val_loss: 0.8714 - val_accuracy: 0.7379

# %%
tf.keras.backend.clear_session()
model4 = tf.keras.models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((3, 3)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(12, activation='softmax')
])
model4.summary()
model4, history4 = compile(model4, 10)
evaluate(history4)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 48, 48, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 44, 44, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       147584
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 256)       295168
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 590,156
# Trainable params: 590,156
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 441/441 [==============================] - 23s 48ms/step - loss: 2.0750 - accuracy: 0.3387 - val_loss: 1.7964 - val_accuracy: 0.4124
# Epoch 2/10
# 441/441 [==============================] - 19s 44ms/step - loss: 1.6387 - accuracy: 0.4521 - val_loss: 1.4113 - val_accuracy: 0.5247
# Epoch 3/10
# 441/441 [==============================] - 19s 44ms/step - loss: 1.3965 - accuracy: 0.5362 - val_loss: 1.3435 - val_accuracy: 0.5644
# Epoch 4/10
# 441/441 [==============================] - 20s 45ms/step - loss: 1.2503 - accuracy: 0.5844 - val_loss: 1.1601 - val_accuracy: 0.6035
# Epoch 5/10
# 441/441 [==============================] - 19s 44ms/step - loss: 1.1338 - accuracy: 0.6238 - val_loss: 1.0828 - val_accuracy: 0.6344
# Epoch 6/10
# 441/441 [==============================] - 19s 44ms/step - loss: 1.0276 - accuracy: 0.6583 - val_loss: 1.0095 - val_accuracy: 0.6588
# Epoch 7/10
# 441/441 [==============================] - 20s 44ms/step - loss: 0.9584 - accuracy: 0.6823 - val_loss: 0.9513 - val_accuracy: 0.6818
# Epoch 8/10
# 441/441 [==============================] - 19s 44ms/step - loss: 0.8911 - accuracy: 0.7047 - val_loss: 0.9578 - val_accuracy: 0.6889
# Epoch 9/10
# 441/441 [==============================] - 19s 44ms/step - loss: 0.8150 - accuracy: 0.7237 - val_loss: 0.9022 - val_accuracy: 0.7124
# Epoch 10/10
# 441/441 [==============================] - 20s 45ms/step - loss: 0.7610 - accuracy: 0.7459 - val_loss: 0.8884 - val_accuracy: 0.7076

# %%
tf.keras.backend.clear_session()
model5 = tf.keras.models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((3, 3)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(12, activation='softmax')
])
model5.summary()
model5, history5 = compile(model5, 17)
evaluate(history5)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 94, 94, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 64)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        36928
#
#  conv2d_4 (Conv2D)           (None, 43, 43, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 11, 11, 128)       147584
#
#  conv2d_7 (Conv2D)           (None, 9, 9, 256)         295168
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 256)         590080
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               32896
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 1,389,452
# Trainable params: 1,389,452
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/17
# 441/441 [==============================] - 35s 76ms/step - loss: 2.1887 - accuracy: 0.2978 - val_loss: 2.1544 - val_accuracy: 0.2995
# Epoch 2/17
# 441/441 [==============================] - 34s 76ms/step - loss: 2.1548 - accuracy: 0.3023 - val_loss: 2.1618 - val_accuracy: 0.2995
# Epoch 3/17
# 441/441 [==============================] - 34s 76ms/step - loss: 2.1493 - accuracy: 0.3017 - val_loss: 2.1440 - val_accuracy: 0.3009
# Epoch 4/17
# 441/441 [==============================] - 34s 76ms/step - loss: 2.0526 - accuracy: 0.3139 - val_loss: 1.9371 - val_accuracy: 0.3389
# Epoch 5/17
# 441/441 [==============================] - 34s 76ms/step - loss: 1.8096 - accuracy: 0.3852 - val_loss: 1.6742 - val_accuracy: 0.4192
# Epoch 6/17
# 441/441 [==============================] - 34s 76ms/step - loss: 1.6287 - accuracy: 0.4459 - val_loss: 1.5393 - val_accuracy: 0.4770
# Epoch 7/17
# 441/441 [==============================] - 34s 77ms/step - loss: 1.4804 - accuracy: 0.4960 - val_loss: 1.4562 - val_accuracy: 0.5111
# Epoch 8/17
# 441/441 [==============================] - 34s 77ms/step - loss: 1.3484 - accuracy: 0.5540 - val_loss: 1.2765 - val_accuracy: 0.5803
# Epoch 9/17
# 441/441 [==============================] - 34s 77ms/step - loss: 1.2242 - accuracy: 0.5966 - val_loss: 1.2759 - val_accuracy: 0.5777
# Epoch 10/17
# 441/441 [==============================] - 34s 77ms/step - loss: 1.1228 - accuracy: 0.6281 - val_loss: 1.1251 - val_accuracy: 0.6375
# Epoch 11/17
# 441/441 [==============================] - 34s 77ms/step - loss: 1.0209 - accuracy: 0.6659 - val_loss: 1.1187 - val_accuracy: 0.6288
# Epoch 12/17
# 441/441 [==============================] - 34s 78ms/step - loss: 0.9162 - accuracy: 0.6974 - val_loss: 1.0359 - val_accuracy: 0.6611
# Epoch 13/17
# 441/441 [==============================] - 34s 77ms/step - loss: 0.8252 - accuracy: 0.7227 - val_loss: 1.0719 - val_accuracy: 0.6455
# Epoch 14/17
# 441/441 [==============================] - 34s 78ms/step - loss: 0.7528 - accuracy: 0.7455 - val_loss: 1.1085 - val_accuracy: 0.6642
# Epoch 15/17
# 441/441 [==============================] - 34s 78ms/step - loss: 0.6714 - accuracy: 0.7746 - val_loss: 1.1476 - val_accuracy: 0.6645
# Epoch 16/17
# 441/441 [==============================] - 34s 78ms/step - loss: 0.6101 - accuracy: 0.7943 - val_loss: 1.0944 - val_accuracy: 0.6727
# Epoch 17/17
# 441/441 [==============================] - 34s 78ms/step - loss: 0.5549 - accuracy: 0.8142 - val_loss: 1.0661 - val_accuracy: 0.6843

# %%
tf.keras.backend.clear_session()
model6 = tf.keras.models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, (3, 3), activation='relu'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(12, activation='softmax')
])
model6.summary()
model6, history6 = compile(model6, 17)
evaluate(history6)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 256)         295168
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 405,644
# Trainable params: 405,644
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/17
# 441/441 [==============================] - 9s 19ms/step - loss: 2.1565 - accuracy: 0.3480 - val_loss: 1.7286 - val_accuracy: 0.4243
# Epoch 2/17
# 441/441 [==============================] - 8s 18ms/step - loss: 1.5622 - accuracy: 0.4796 - val_loss: 1.3950 - val_accuracy: 0.5403
# Epoch 3/17
# 441/441 [==============================] - 8s 18ms/step - loss: 1.3448 - accuracy: 0.5529 - val_loss: 1.2514 - val_accuracy: 0.5916
# Epoch 4/17
# 441/441 [==============================] - 8s 18ms/step - loss: 1.1992 - accuracy: 0.6030 - val_loss: 1.1123 - val_accuracy: 0.6237
# Epoch 5/17
# 441/441 [==============================] - 8s 18ms/step - loss: 1.0821 - accuracy: 0.6415 - val_loss: 1.0408 - val_accuracy: 0.6444
# Epoch 6/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.9857 - accuracy: 0.6699 - val_loss: 0.9172 - val_accuracy: 0.6931
# Epoch 7/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.9049 - accuracy: 0.6962 - val_loss: 0.9082 - val_accuracy: 0.7019
# Epoch 8/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.8308 - accuracy: 0.7206 - val_loss: 0.8803 - val_accuracy: 0.7033
# Epoch 9/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.7578 - accuracy: 0.7445 - val_loss: 0.8339 - val_accuracy: 0.7272
# Epoch 10/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.6778 - accuracy: 0.7685 - val_loss: 0.8716 - val_accuracy: 0.7127
# Epoch 11/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.6442 - accuracy: 0.7792 - val_loss: 0.9219 - val_accuracy: 0.7102
# Epoch 12/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.5667 - accuracy: 0.8044 - val_loss: 0.8950 - val_accuracy: 0.7170
# Epoch 13/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.5311 - accuracy: 0.8163 - val_loss: 0.8116 - val_accuracy: 0.7482
# Epoch 14/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.4500 - accuracy: 0.8416 - val_loss: 0.9702 - val_accuracy: 0.7297
# Epoch 15/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.4148 - accuracy: 0.8534 - val_loss: 0.9032 - val_accuracy: 0.7459
# Epoch 16/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.3744 - accuracy: 0.8704 - val_loss: 0.9386 - val_accuracy: 0.7450
# Epoch 17/17
# 441/441 [==============================] - 8s 18ms/step - loss: 0.3212 - accuracy: 0.8847 - val_loss: 0.9266 - val_accuracy: 0.7377

# %%
tf.keras.backend.clear_session()
tester = tf.keras.models.Sequential([
    # Block 1
    layers.Conv2D(16, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    # Block 2
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    # Block 3
    layers.Conv2D(256, (3, 3), activation='relu'),
    # Convert to 1 dimensional array
    layers.GlobalAveragePooling2D(),
    # Use dense to capture the patterns and produce output
    layers.Dense(128, activation='relu'),
    layers.Dropout(rate=0.35),
    layers.Dense(12, activation='softmax')
])
tester.summary()
testmodel, historytest = compile(tester, 20)
evaluate(historytest)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 32)        4640
#
#  conv2d_2 (Conv2D)           (None, 94, 94, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 64)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 20, 20, 256)       295168
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 427,052
# Trainable params: 427,052
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 441/441 [==============================] - 36s 61ms/step - loss: 2.0334 - accuracy: 0.3500 - val_loss: 1.5928 - val_accuracy: 0.4699
# Epoch 2/20
# 441/441 [==============================] - 26s 58ms/step - loss: 1.5704 - accuracy: 0.4848 - val_loss: 1.3480 - val_accuracy: 0.5769
# Epoch 3/20
# 441/441 [==============================] - 26s 59ms/step - loss: 1.3546 - accuracy: 0.5497 - val_loss: 1.2242 - val_accuracy: 0.5942
# Epoch 4/20
# 441/441 [==============================] - 26s 59ms/step - loss: 1.2204 - accuracy: 0.6017 - val_loss: 1.0934 - val_accuracy: 0.6361
# Epoch 5/20
# 441/441 [==============================] - 26s 60ms/step - loss: 1.0994 - accuracy: 0.6421 - val_loss: 0.9997 - val_accuracy: 0.6690
# Epoch 6/20
# 441/441 [==============================] - 28s 63ms/step - loss: 1.0081 - accuracy: 0.6722 - val_loss: 0.9747 - val_accuracy: 0.6787
# Epoch 7/20
# 441/441 [==============================] - 28s 62ms/step - loss: 0.9179 - accuracy: 0.6968 - val_loss: 0.9281 - val_accuracy: 0.6948
# Epoch 8/20
# 441/441 [==============================] - 28s 63ms/step - loss: 0.8476 - accuracy: 0.7215 - val_loss: 0.9073 - val_accuracy: 0.7014
# Epoch 9/20
# 441/441 [==============================] - 28s 63ms/step - loss: 0.8034 - accuracy: 0.7319 - val_loss: 0.7817 - val_accuracy: 0.7402
# Epoch 10/20
# 441/441 [==============================] - 28s 63ms/step - loss: 0.7352 - accuracy: 0.7550 - val_loss: 0.7985 - val_accuracy: 0.7326
# Epoch 11/20
# 441/441 [==============================] - 28s 63ms/step - loss: 0.6966 - accuracy: 0.7634 - val_loss: 0.7450 - val_accuracy: 0.7473
# Epoch 12/20
# 441/441 [==============================] - 29s 66ms/step - loss: 0.6249 - accuracy: 0.7857 - val_loss: 0.7507 - val_accuracy: 0.7544
# Epoch 13/20
# 441/441 [==============================] - 29s 65ms/step - loss: 0.5944 - accuracy: 0.7981 - val_loss: 0.6994 - val_accuracy: 0.7473
# Epoch 14/20
# 441/441 [==============================] - 27s 62ms/step - loss: 0.5470 - accuracy: 0.8105 - val_loss: 0.7271 - val_accuracy: 0.7535
# Epoch 15/20
# 441/441 [==============================] - 27s 62ms/step - loss: 0.5116 - accuracy: 0.8228 - val_loss: 0.7304 - val_accuracy: 0.7734
# Epoch 16/20
# 441/441 [==============================] - 27s 62ms/step - loss: 0.4666 - accuracy: 0.8407 - val_loss: 0.7070 - val_accuracy: 0.7703
# Epoch 17/20
# 441/441 [==============================] - 27s 62ms/step - loss: 0.4084 - accuracy: 0.8599 - val_loss: 0.8007 - val_accuracy: 0.7640
# Epoch 18/20
# 441/441 [==============================] - 27s 62ms/step - loss: 0.3919 - accuracy: 0.8633 - val_loss: 0.7959 - val_accuracy: 0.7655
# Epoch 19/20
# 441/441 [==============================] - 27s 62ms/step - loss: 0.3500 - accuracy: 0.8747 - val_loss: 0.8468 - val_accuracy: 0.7567
# Epoch 20/20
# 441/441 [==============================] - 27s 62ms/step - loss: 0.3463 - accuracy: 0.8820 - val_loss: 0.7974 - val_accuracy: 0.7774
